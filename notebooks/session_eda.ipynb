# %%
import pandas as pd

tunes = pd.read_json("../data/tunes.json")
tunes.head()
# Out:
#    tune_id  setting_id                         name        type meter    mode  \
# 0    15326       28560                'S Ann An Ìle  strathspey   4/4  Gmajor
# 1    15326       28582                'S Ann An Ìle  strathspey   4/4  Gmajor
# 2    14625       26955             'S Daor An Tabac        reel   4/4  Bminor
# 3     5478        5478  'S Iomadh Rud A Chunnaic Mi        reel   4/4  Gmajor
# 4     5478       11429  'S Iomadh Rud A Chunnaic Mi        reel   4/4  Dmajor
#
#                                                  abc                date  \
# 0  |:G>A B>G c>A B>G|E<E A>G F<D D2|G>A B>G c>A B... 2016-03-31 15:34:45
# 1  uD2|:{F}v[G,2G2]uB>ud c>A B>G|{D}E2 uA>uG F<D ... 2016-04-03 09:15:08
# 2  |:eAAB eABB|eAAB gedB|eAAB eABB|G2AB gedB:|\r\... 2015-07-31 02:47:47
# 3  ABBA GEDE|G2AG EGDG|ABBA GEDE|GEDE G2GA|\r\nAB... 2006-02-03 04:45:46
# 4  |:e|f2fe dBAB|dded B2A2|f2fe dBAB|dBAB d2d:|\r... 2011-08-17 00:57:48
#
#             username composer
# 0          danninagh
# ...

# %%
for col in ["type", "meter", "mode"]:
    values = sorted(tunes[col].dropna().unique())
    print(f"\n{col} ({len(values)} unique):")
    print(values)
# Out:
# type (12 unique):
# ['barndance', 'hornpipe', 'jig', 'march', 'mazurka', 'polka', 'reel', 'slide', 'slip jig', 'strathspey', 'three-two', 'waltz']
#
# meter (7 unique):
# ['12/8', '2/4', '3/2', '3/4', '4/4', '6/8', '9/8']
#
# mode (23 unique):
# ['Adorian', 'Amajor', 'Aminor', 'Amixolydian', 'Bdorian', 'Bminor', 'Bmixolydian', 'Cdorian', 'Cmajor', 'Ddorian', 'Dmajor', 'Dminor', 'Dmixolydian', 'Edorian', 'Emajor', 'Eminor', 'Emixolydian', 'Fdorian', 'Fmajor', 'Gdorian', 'Gmajor', 'Gminor', 'Gmixolydian']

# %%
tunes.isnull().sum()
# Out:
# tune_id       0
# setting_id    0
# name          0
# type          0
# meter         0
# mode          0
# abc           0
# date          0
# username      0
# composer      0
# dtype: int64

# %%
tunes.shape
# Out:
# (54246, 10)
